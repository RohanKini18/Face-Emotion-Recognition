# %%
from keras.utils import to_categorical
from keras.preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import load_img
# Out:
# WARNING:tensorflow:From C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
TRAIN_DIR = 'images/train'
TEST_DIR = 'images/test'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths,labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(train)
# Out:
#                                 image     label
# 0            images/train\angry\0.jpg     angry
# 1            images/train\angry\1.jpg     angry
# 2           images/train\angry\10.jpg     angry
# 3        images/train\angry\10002.jpg     angry
# 4        images/train\angry\10016.jpg     angry
# ...                               ...       ...
# 28816  images/train\surprise\9969.jpg  surprise
# 28817  images/train\surprise\9985.jpg  surprise
# 28818  images/train\surprise\9990.jpg  surprise
# 28819  images/train\surprise\9992.jpg  surprise
# 28820  images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(test)
print(test['image'])
# Out:
#                               image     label
# 0       images/test\angry\10052.jpg     angry
# 1       images/test\angry\10065.jpg     angry
# 2       images/test\angry\10079.jpg     angry
# 3       images/test\angry\10095.jpg     angry
# 4       images/test\angry\10121.jpg     angry
# ...                             ...       ...
# 7061  images/test\surprise\9806.jpg  surprise
# 7062  images/test\surprise\9830.jpg  surprise
# 7063  images/test\surprise\9853.jpg  surprise
# 7064  images/test\surprise\9878.jpg  surprise
# 7065   images/test\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]
# 0         images/test\angry\10052.jpg
# 1         images/test\angry\10065.jpg
# 2         images/test\angry\10079.jpg
# 3         images/test\angry\10095.jpg
# 4         images/test\angry\10121.jpg
#                     ...
# 7061    images/test\surprise\9806.jpg
# 7062    images/test\surprise\9830.jpg
# 7063    images/test\surprise\9853.jpg
# 7064    images/test\surprise\9878.jpg
# 7065     images/test\surprise\993.jpg
# Name: image, Length: 7066, dtype: object

# %%
from tqdm.notebook import tqdm
from PIL import Image
from keras.preprocessing.image import img_to_array
from keras.models import load_model

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image,grayscale =  True )
      
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features),48,48,1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]
# C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %%
model = Sequential()
# convolutional layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
# fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
# output layer
model.add(Dense(7, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = 'accuracy' )
# Out:
# WARNING:tensorflow:From C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(x= x_train,y = y_train, batch_size = 128, epochs = 100, validation_data = (x_test,y_test))
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 226/226 [==============================] - 581s 3s/step - loss: 1.8244 - accuracy: 0.2426 - val_loss: 1.8112 - val_accuracy: 0.2583
# Epoch 2/100
# 226/226 [==============================] - 562s 2s/step - loss: 1.8009 - accuracy: 0.2529 - val_loss: 1.7732 - val_accuracy: 0.2622
# Epoch 3/100
# 226/226 [==============================] - 578s 3s/step - loss: 1.7134 - accuracy: 0.3047 - val_loss: 1.6032 - val_accuracy: 0.3701
# Epoch 4/100
# 226/226 [==============================] - 567s 3s/step - loss: 1.5766 - accuracy: 0.3793 - val_loss: 1.4261 - val_accuracy: 0.4421
# Epoch 5/100
# 226/226 [==============================] - 570s 3s/step - loss: 1.4938 - accuracy: 0.4218 - val_loss: 1.3516 - val_accuracy: 0.4904
# Epoch 6/100
# 226/226 [==============================] - 574s 3s/step - loss: 1.4411 - accuracy: 0.4438 - val_loss: 1.3154 - val_accuracy: 0.4911
# Epoch 7/100
# 226/226 [==============================] - 563s 2s/step - loss: 1.3948 - accuracy: 0.4652 - val_loss: 1.2816 - val_accuracy: 0.5051
# Epoch 8/100
# 226/226 [==============================] - 610s 3s/step - loss: 1.3576 - accuracy: 0.4773 - val_loss: 1.2542 - val_accuracy: 0.5211
# Epoch 9/100
# 226/226 [==============================] - 600s 3s/step - loss: 1.3345 - accuracy: 0.4869 - val_loss: 1.2282 - val_accuracy: 0.5273
# Epoch 10/100
# 226/226 [==============================] - 589s 3s/step - loss: 1.3037 - accuracy: 0.5023 - val_loss: 1.2050 - val_accuracy: 0.5501
# Epoch 11/100
# 226/226 [==============================] - 573s 3s/step - loss: 1.2920 - accuracy: 0.5066 - val_loss: 1.2264 - val_accuracy: 0.5297
# Epoch 12/100
# 226/226 [==============================] - 578s 3s/step - loss: 1.2761 - accuracy: 0.5131 - val_loss: 1.1664 - val_accuracy: 0.5584
# Epoch 13/100
# 226/226 [==============================] - 709s 3s/step - loss: 1.2570 - accuracy: 0.5202 - val_loss: 1.1717 - val_accuracy: 0.5519
# Epoch 14/100
# 226/226 [==============================] - 803s 4s/step - loss: 1.2432 - accuracy: 0.5276 - val_loss: 1.1845 - val_accuracy: 0.5517
# 226/226 [==============================] - 645s 3s/step - loss: 0.8012 - accuracy: 0.7067 - val_loss: 1.0298 - val_accuracy: 0.6282
# Epoch 91/100
# 226/226 [==============================] - 648s 3s/step - loss: 0.7919 - accuracy: 0.7104 - val_loss: 1.0318 - val_accuracy: 0.6250
# Epoch 92/100
# 226/226 [==============================] - 637s 3s/step - loss: 0.7916 - accuracy: 0.7094 - val_loss: 1.0324 - val_accuracy: 0.6329
# Epoch 93/100
# 226/226 [==============================] - 637s 3s/step - loss: 0.7922 - accuracy: 0.7085 - val_loss: 1.0325 - val_accuracy: 0.6258
# Epoch 94/100
# 226/226 [==============================] - 642s 3s/step - loss: 0.7858 - accuracy: 0.7135 - val_loss: 1.0350 - val_accuracy: 0.6305
# Epoch 95/100
# 226/226 [==============================] - 635s 3s/step - loss: 0.7758 - accuracy: 0.7154 - val_loss: 1.0319 - val_accuracy: 0.6357
# Epoch 96/100
# 226/226 [==============================] - 644s 3s/step - loss: 0.7732 - accuracy: 0.7220 - val_loss: 1.0286 - val_accuracy: 0.6343
# Epoch 97/100
# 226/226 [==============================] - 655s 3s/step - loss: 0.7785 - accuracy: 0.7155 - val_loss: 1.0300 - val_accuracy: 0.6284
# Epoch 98/100
# 226/226 [==============================] - 640s 3s/step - loss: 0.7770 - accuracy: 0.7165 - val_loss: 1.0218 - val_accuracy: 0.6305
# Epoch 99/100
# 226/226 [==============================] - 635s 3s/step - loss: 0.7766 - accuracy: 0.7162 - val_loss: 1.0349 - val_accuracy: 0.6275
# Epoch 100/100
# 226/226 [==============================] - 635s 3s/step - loss: 0.7659 - accuracy: 0.7209 - val_loss: 1.0253 - val_accuracy: 0.6330

# %%
model_json = model.to_json()
with open("emotiondetector.json",'w') as json_file:
    json_file.write(model_json)
model.save("emotiondetector.h5")
# Out:
# C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.models import model_from_json

# %%
json_file = open("emotiondetector.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("emotiondetector.h5")

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image,grayscale =  True )
    feature = np.array(img)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

# %%
image = 'images/train/sad/42.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
# Out:
# original image is of sad
# C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(
# 1/1 [==============================] - 2s 2s/step
# model prediction is  fear

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = 'images/train/sad/42.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of sad
# C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(
# 1/1 [==============================] - 1s 957ms/step
# model prediction is  fear

# %%
image = 'images/train/fear/2.jpg'
print("original image is of fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of fear
# 1/1 [==============================] - 0s 299ms/step
# model prediction is  fear

# %%
image = 'images/train/disgust/299.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of disgust
# 1/1 [==============================] - 0s 222ms/step
# model prediction is  disgust

# %%
image = 'images/train/happy/7.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 [==============================] - 0s 212ms/step
# model prediction is  happy

# %%
image = 'images/train/surprise/15.jpg'
print("original image is of surprise")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of surprise
# 1/1 [==============================] - 0s 332ms/step
# model prediction is  surprise

# %%
from keras.models import model_from_json
# Out:
# WARNING:tensorflow:From C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
json_file = open("emotiondetector.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("emotiondetector.h5")
# Out:
# WARNING:tensorflow:From C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image,grayscale =  True )
    feature = np.array(img)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
from tqdm.notebook import tqdm
from keras.utils import to_categorical
from keras.preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
image = 'images/train/sad/6.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
# Out:
# original image is of sad
# C:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(
# 1/1 [==============================] - 0s 477ms/step
# model prediction is  sad

# %%
image = 'images/train/sad/6.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of sad
# 1/1 [==============================] - 0s 47ms/step
# model prediction is  sad

# %%
image = 'images/train/fear/292.jpg'
print("original image is of fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of fear
# 1/1 [==============================] - 0s 95ms/step
# model prediction is  fear

# %%
image = 'images/train/fear/300.jpg'
print("original image is of fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of fear
# 1/1 [==============================] - 0s 63ms/step
# model prediction is  fear

# %%
image = 'images/train/fear/862.jpg'
print("original image is of fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of fear
# 1/1 [==============================] - 0s 76ms/step
# model prediction is  fear

# %%
image = 'images/train/fear/983.jpg'
print("original image is of fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of fear
# 1/1 [==============================] - 0s 53ms/step
# model prediction is  fear

# %%
image = 'images/train/angry/342.jpg'
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of angry
# 1/1 [==============================] - 0s 64ms/step
# model prediction is  angry

# %%
image = 'images/train/angry/464.jpg'
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of angry
# 1/1 [==============================] - 0s 69ms/step
# model prediction is  angry

# %%
image = 'images/train/angry/883.jpg'
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of angry
# 1/1 [==============================] - 0s 53ms/step
# model prediction is  angry

# %%
image = 'images/train/angry/962.jpg'
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of angry
# 1/1 [==============================] - 0s 70ms/step
# model prediction is  angry

# %%
image = 'images/train/sad/318.jpg'
print("original image is of  sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of  sad
# 1/1 [==============================] - 0s 64ms/step
# model prediction is  sad

# %%
image = 'images/train/sad/58.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of sad
# 1/1 [==============================] - 0s 49ms/step
# model prediction is  neutral

# %%
image = 'images/train/sad/616.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of sad
# 1/1 [==============================] - 0s 69ms/step
# model prediction is  sad

# %%
image = 'images/train/neutral/35.jpg'
print("original image is of neutral")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of neutral
# 1/1 [==============================] - 0s 46ms/step
# model prediction is  neutral

# %%
image = 'images/train/neutral/250.jpg'
print("original image is of netural")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of netural
# 1/1 [==============================] - 0s 54ms/step
# model prediction is  neutral

# %%
image = 'images/train/happy/14.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 [==============================] - 0s 37ms/step
# model prediction is  happy

# %%
image = 'images/train/happy/46.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 [==============================] - 0s 51ms/step
# model prediction is  happy

# %%
image = 'images/train/happy/57.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 [==============================] - 0s 39ms/step
# model prediction is  happy

# %%
image = 'images/train/disgust/388.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of disgust
# 1/1 [==============================] - 0s 47ms/step
# model prediction is  disgust

# %%
image = 'images/train/disgust/416.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of disgust
# 1/1 [==============================] - 0s 43ms/step
# model prediction is  disgust

# %%
image = 'images/train/disgust/473.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of disgust
# 1/1 [==============================] - 0s 31ms/step
# model prediction is  disgust

# %%
image = 'images/train/disgust/2321.jpg'
print("original image is of fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of fear
# 1/1 [==============================] - 0s 64ms/step
# model prediction is  disgust

# %%
image = 'images/train/disgust/4078.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of disgust
# 1/1 [==============================] - 0s 46ms/step
# model prediction is  disgust
